# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\babu ram\anaconda\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\babu ram\anaconda\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\babu ram\anaconda\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\babu ram\anaconda\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\babu ram\anaconda\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\babu ram\anaconda\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import pandas as pd
df = pd.read_csv('Salary Data.csv')
df
# Out:
#       Age  Gender Education Level                      Job Title  \
# 0    32.0    Male      Bachelor's              Software Engineer
# 1    28.0  Female        Master's                   Data Analyst
# 2    45.0    Male             PhD                 Senior Manager
# 3    36.0  Female      Bachelor's                Sales Associate
# 4    52.0    Male        Master's                       Director
# ..    ...     ...             ...                            ...
# 370  35.0  Female      Bachelor's       Senior Marketing Analyst
# 371  43.0    Male        Master's         Director of Operations
# 372  29.0  Female      Bachelor's         Junior Project Manager
# 373  34.0    Male      Bachelor's  Senior Operations Coordinator
# 374  44.0  Female             PhD        Senior Business Analyst
#
#      Years of Experience    Salary
# 0                    5.0   90000.0
# 1                    3.0   65000.0
# 2                   15.0  150000.0
# 3                    7.0   60000.0
# 4                   20.0  200000.0
# ..                   ...       ...
# 370                  8.0   85000.0
# 371                 19.0  170000.0
# 372                  2.0   40000.0
# 373                  7.0   90000.0
# 374                 15.0  150000.0
#
# [375 rows x 6 columns]

# %%
import pandas as pd
df = pd.read_csv('Salary Data.csv')
df
# Out:
#       Age  Gender Education Level                      Job Title  \
# 0    32.0    Male      Bachelor's              Software Engineer
# 1    28.0  Female        Master's                   Data Analyst
# 2    45.0    Male             PhD                 Senior Manager
# 3    36.0  Female      Bachelor's                Sales Associate
# 4    52.0    Male        Master's                       Director
# ..    ...     ...             ...                            ...
# 370  35.0  Female      Bachelor's       Senior Marketing Analyst
# 371  43.0    Male        Master's         Director of Operations
# 372  29.0  Female      Bachelor's         Junior Project Manager
# 373  34.0    Male      Bachelor's  Senior Operations Coordinator
# 374  44.0  Female             PhD        Senior Business Analyst
#
#      Years of Experience    Salary
# 0                    5.0   90000.0
# 1                    3.0   65000.0
# 2                   15.0  150000.0
# 3                    7.0   60000.0
# 4                   20.0  200000.0
# ..                   ...       ...
# 370                  8.0   85000.0
# 371                 19.0  170000.0
# 372                  2.0   40000.0
# 373                  7.0   90000.0
# 374                 15.0  150000.0
#
# [375 rows x 6 columns]

# %%
import pandas as pd
df = pd.read_csv('Salary Data.csv')
df
# Out:
#       Age  Gender Education Level                      Job Title  \
# 0    32.0    Male      Bachelor's              Software Engineer
# 1    28.0  Female        Master's                   Data Analyst
# 2    45.0    Male             PhD                 Senior Manager
# 3    36.0  Female      Bachelor's                Sales Associate
# 4    52.0    Male        Master's                       Director
# ..    ...     ...             ...                            ...
# 370  35.0  Female      Bachelor's       Senior Marketing Analyst
# 371  43.0    Male        Master's         Director of Operations
# 372  29.0  Female      Bachelor's         Junior Project Manager
# 373  34.0    Male      Bachelor's  Senior Operations Coordinator
# 374  44.0  Female             PhD        Senior Business Analyst
#
#      Years of Experience    Salary
# 0                    5.0   90000.0
# 1                    3.0   65000.0
# 2                   15.0  150000.0
# 3                    7.0   60000.0
# 4                   20.0  200000.0
# ..                   ...       ...
# 370                  8.0   85000.0
# 371                 19.0  170000.0
# 372                  2.0   40000.0
# 373                  7.0   90000.0
# 374                 15.0  150000.0
#
# [375 rows x 6 columns]

# %%
df.head()
# Out:
#     Age  Gender Education Level          Job Title  Years of Experience  \
# 0  32.0    Male      Bachelor's  Software Engineer                  5.0
# 1  28.0  Female        Master's       Data Analyst                  3.0
# 2  45.0    Male             PhD     Senior Manager                 15.0
# 3  36.0  Female      Bachelor's    Sales Associate                  7.0
# 4  52.0    Male        Master's           Director                 20.0
#
#      Salary
# 0   90000.0
# 1   65000.0
# 2  150000.0
# 3   60000.0
# 4  200000.0

# %%
df.head()
# Out:
#     Age  Gender Education Level          Job Title  Years of Experience  \
# 0  32.0    Male      Bachelor's  Software Engineer                  5.0
# 1  28.0  Female        Master's       Data Analyst                  3.0
# 2  45.0    Male             PhD     Senior Manager                 15.0
# 3  36.0  Female      Bachelor's    Sales Associate                  7.0
# 4  52.0    Male        Master's           Director                 20.0
#
#      Salary
# 0   90000.0
# 1   65000.0
# 2  150000.0
# 3   60000.0
# 4  200000.0

# %%
df.tail()
# Out:
#       Age  Gender Education Level                      Job Title  \
# 370  35.0  Female      Bachelor's       Senior Marketing Analyst
# 371  43.0    Male        Master's         Director of Operations
# 372  29.0  Female      Bachelor's         Junior Project Manager
# 373  34.0    Male      Bachelor's  Senior Operations Coordinator
# 374  44.0  Female             PhD        Senior Business Analyst
#
#      Years of Experience    Salary
# 370                  8.0   85000.0
# 371                 19.0  170000.0
# 372                  2.0   40000.0
# 373                  7.0   90000.0
# 374                 15.0  150000.0

# %%
df.tail()
# Out:
#       Age  Gender Education Level                      Job Title  \
# 370  35.0  Female      Bachelor's       Senior Marketing Analyst
# 371  43.0    Male        Master's         Director of Operations
# 372  29.0  Female      Bachelor's         Junior Project Manager
# 373  34.0    Male      Bachelor's  Senior Operations Coordinator
# 374  44.0  Female             PhD        Senior Business Analyst
#
#      Years of Experience    Salary
# 370                  8.0   85000.0
# 371                 19.0  170000.0
# 372                  2.0   40000.0
# 373                  7.0   90000.0
# 374                 15.0  150000.0

# %%
df = pd.read_csv('salary Data.csv',nrows = 5)
df
# Out:
#    Age  Gender Education Level          Job Title  Years of Experience  Salary
# 0   32    Male      Bachelor's  Software Engineer                    5   90000
# 1   28  Female        Master's       Data Analyst                    3   65000
# 2   45    Male             PhD     Senior Manager                   15  150000
# 3   36  Female      Bachelor's    Sales Associate                    7   60000
# 4   52    Male        Master's           Director                   20  200000

# %%
df = pd.read_csv('salary Data.csv',nrows = 5)
df
# Out:
#    Age  Gender Education Level          Job Title  Years of Experience  Salary
# 0   32    Male      Bachelor's  Software Engineer                    5   90000
# 1   28  Female        Master's       Data Analyst                    3   65000
# 2   45    Male             PhD     Senior Manager                   15  150000
# 3   36  Female      Bachelor's    Sales Associate                    7   60000
# 4   52    Male        Master's           Director                   20  200000

# %%
col = ['Years of Experience','Salary']
df = pd.read_csv('Salary Data.csv',usecols = col)
df
# Out:
#      Years of Experience    Salary
# 0                    5.0   90000.0
# 1                    3.0   65000.0
# 2                   15.0  150000.0
# 3                    7.0   60000.0
# 4                   20.0  200000.0
# ..                   ...       ...
# 370                  8.0   85000.0
# 371                 19.0  170000.0
# 372                  2.0   40000.0
# 373                  7.0   90000.0
# 374                 15.0  150000.0
#
# [375 rows x 2 columns]

# %%
col = ['Years of Experience','Salary']
df = pd.read_csv('Salary Data.csv',usecols = col)
df
# Out:
#      Years of Experience    Salary
# 0                    5.0   90000.0
# 1                    3.0   65000.0
# 2                   15.0  150000.0
# 3                    7.0   60000.0
# 4                   20.0  200000.0
# ..                   ...       ...
# 370                  8.0   85000.0
# 371                 19.0  170000.0
# 372                  2.0   40000.0
# 373                  7.0   90000.0
# 374                 15.0  150000.0
#
# [375 rows x 2 columns]

# %%
col = ['Years of Experience','Salary']
df = pd.read_csv('Salary Data.csv',usecols = col)
df
# Out:
#      Years of Experience    Salary
# 0                    5.0   90000.0
# 1                    3.0   65000.0
# 2                   15.0  150000.0
# 3                    7.0   60000.0
# 4                   20.0  200000.0
# ..                   ...       ...
# 370                  8.0   85000.0
# 371                 19.0  170000.0
# 372                  2.0   40000.0
# 373                  7.0   90000.0
# 374                 15.0  150000.0
#
# [375 rows x 2 columns]

# %%
# iloc
df = pd.read_csv('Salary Data.csv')
df
# Out:
#       Age  Gender Education Level                      Job Title  \
# 0    32.0    Male      Bachelor's              Software Engineer
# 1    28.0  Female        Master's                   Data Analyst
# 2    45.0    Male             PhD                 Senior Manager
# 3    36.0  Female      Bachelor's                Sales Associate
# 4    52.0    Male        Master's                       Director
# ..    ...     ...             ...                            ...
# 370  35.0  Female      Bachelor's       Senior Marketing Analyst
# 371  43.0    Male        Master's         Director of Operations
# 372  29.0  Female      Bachelor's         Junior Project Manager
# 373  34.0    Male      Bachelor's  Senior Operations Coordinator
# 374  44.0  Female             PhD        Senior Business Analyst
#
#      Years of Experience    Salary
# 0                    5.0   90000.0
# 1                    3.0   65000.0
# 2                   15.0  150000.0
# 3                    7.0   60000.0
# 4                   20.0  200000.0
# ..                   ...       ...
# 370                  8.0   85000.0
# 371                 19.0  170000.0
# 372                  2.0   40000.0
# 373                  7.0   90000.0
# 374                 15.0  150000.0
#
# [375 rows x 6 columns]

# %%
# iloc
df = pd.read_csv('Salary Data.csv')
df
# Out:
#       Age  Gender Education Level                      Job Title  \
# 0    32.0    Male      Bachelor's              Software Engineer
# 1    28.0  Female        Master's                   Data Analyst
# 2    45.0    Male             PhD                 Senior Manager
# 3    36.0  Female      Bachelor's                Sales Associate
# 4    52.0    Male        Master's                       Director
# ..    ...     ...             ...                            ...
# 370  35.0  Female      Bachelor's       Senior Marketing Analyst
# 371  43.0    Male        Master's         Director of Operations
# 372  29.0  Female      Bachelor's         Junior Project Manager
# 373  34.0    Male      Bachelor's  Senior Operations Coordinator
# 374  44.0  Female             PhD        Senior Business Analyst
#
#      Years of Experience    Salary
# 0                    5.0   90000.0
# 1                    3.0   65000.0
# 2                   15.0  150000.0
# 3                    7.0   60000.0
# 4                   20.0  200000.0
# ..                   ...       ...
# 370                  8.0   85000.0
# 371                 19.0  170000.0
# 372                  2.0   40000.0
# 373                  7.0   90000.0
# 374                 15.0  150000.0
#
# [375 rows x 6 columns]

# %%
#for row
df.iloc[5:10]
# Out:
#     Age  Gender Education Level              Job Title  Years of Experience  \
# 5  29.0    Male      Bachelor's      Marketing Analyst                  2.0
# 6  42.0  Female        Master's        Product Manager                 12.0
# 7  31.0    Male      Bachelor's          Sales Manager                  4.0
# 8  26.0  Female      Bachelor's  Marketing Coordinator                  1.0
# 9  38.0    Male             PhD       Senior Scientist                 10.0
#
#      Salary
# 5   55000.0
# 6  120000.0
# 7   80000.0
# 8   45000.0
# 9  110000.0

# %%
#for row
df.iloc[5:10]
# Out:
#     Age  Gender Education Level              Job Title  Years of Experience  \
# 5  29.0    Male      Bachelor's      Marketing Analyst                  2.0
# 6  42.0  Female        Master's        Product Manager                 12.0
# 7  31.0    Male      Bachelor's          Sales Manager                  4.0
# 8  26.0  Female      Bachelor's  Marketing Coordinator                  1.0
# 9  38.0    Male             PhD       Senior Scientist                 10.0
#
#      Salary
# 5   55000.0
# 6  120000.0
# 7   80000.0
# 8   45000.0
# 9  110000.0

# %%
#for col
df.iloc[ :, 0:4]
# Out:
#       Age  Gender Education Level                      Job Title
# 0    32.0    Male      Bachelor's              Software Engineer
# 1    28.0  Female        Master's                   Data Analyst
# 2    45.0    Male             PhD                 Senior Manager
# 3    36.0  Female      Bachelor's                Sales Associate
# 4    52.0    Male        Master's                       Director
# ..    ...     ...             ...                            ...
# 370  35.0  Female      Bachelor's       Senior Marketing Analyst
# 371  43.0    Male        Master's         Director of Operations
# 372  29.0  Female      Bachelor's         Junior Project Manager
# 373  34.0    Male      Bachelor's  Senior Operations Coordinator
# 374  44.0  Female             PhD        Senior Business Analyst
#
# [375 rows x 4 columns]

# %%
#for col
df.iloc[ :, 0:4]
# Out:
#       Age  Gender Education Level                      Job Title
# 0    32.0    Male      Bachelor's              Software Engineer
# 1    28.0  Female        Master's                   Data Analyst
# 2    45.0    Male             PhD                 Senior Manager
# 3    36.0  Female      Bachelor's                Sales Associate
# 4    52.0    Male        Master's                       Director
# ..    ...     ...             ...                            ...
# 370  35.0  Female      Bachelor's       Senior Marketing Analyst
# 371  43.0    Male        Master's         Director of Operations
# 372  29.0  Female      Bachelor's         Junior Project Manager
# 373  34.0    Male      Bachelor's  Senior Operations Coordinator
# 374  44.0  Female             PhD        Senior Business Analyst
#
# [375 rows x 4 columns]

# %%
# for row and col
df.iloc[0:5, 0:4]
# Out:
#     Age  Gender Education Level          Job Title
# 0  32.0    Male      Bachelor's  Software Engineer
# 1  28.0  Female        Master's       Data Analyst
# 2  45.0    Male             PhD     Senior Manager
# 3  36.0  Female      Bachelor's    Sales Associate
# 4  52.0    Male        Master's           Director

# %%
# for row and col
df.iloc[0:5, 0:4]
# Out:
#     Age  Gender Education Level          Job Title
# 0  32.0    Male      Bachelor's  Software Engineer
# 1  28.0  Female        Master's       Data Analyst
# 2  45.0    Male             PhD     Senior Manager
# 3  36.0  Female      Bachelor's    Sales Associate
# 4  52.0    Male        Master's           Director

# %%
# filter

# %%
df['Gender']
# Out:
# 0        Male
# 1      Female
# 2        Male
# 3      Female
# 4        Male
#         ...
# 370    Female
# 371      Male
# 372    Female
# 373      Male
# 374    Female
# Name: Gender, Length: 375, dtype: object

# %%
df['Gender']
# Out:
# 0        Male
# 1      Female
# 2        Male
# 3      Female
# 4        Male
#         ...
# 370    Female
# 371      Male
# 372    Female
# 373      Male
# 374    Female
# Name: Gender, Length: 375, dtype: object

# %%
df['Gender']=='Male'
# Out:
# 0       True
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 370    False
# 371     True
# 372    False
# 373     True
# 374    False
# Name: Gender, Length: 375, dtype: bool

# %%
df['Gender']=='Male'
# Out:
# 0       True
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 370    False
# 371     True
# 372    False
# 373     True
# 374    False
# Name: Gender, Length: 375, dtype: bool

# %%
df[df['Gender']== 'Male']
# Out:
#       Age Gender Education Level                      Job Title  \
# 0    32.0   Male      Bachelor's              Software Engineer
# 2    45.0   Male             PhD                 Senior Manager
# 4    52.0   Male        Master's                       Director
# 5    29.0   Male      Bachelor's              Marketing Analyst
# 7    31.0   Male      Bachelor's                  Sales Manager
# ..    ...    ...             ...                            ...
# 365  43.0   Male        Master's          Director of Marketing
# 367  41.0   Male      Bachelor's         Senior Product Manager
# 369  33.0   Male      Bachelor's        Junior Business Analyst
# 371  43.0   Male        Master's         Director of Operations
# 373  34.0   Male      Bachelor's  Senior Operations Coordinator
#
#      Years of Experience    Salary
# 0                    5.0   90000.0
# 2                   15.0  150000.0
# 4                   20.0  200000.0
# 5                    2.0   55000.0
# 7                    4.0   80000.0
# ..                   ...       ...
# 365                 18.0  170000.0
# 367                 14.0  150000.0
# 369                  4.0   60000.0
# 371                 19.0  170000.0
# 373                  7.0   90000.0
#
# [194 rows x 6 columns]

# %%
df[df['Gender']== 'Male']
# Out:
#       Age Gender Education Level                      Job Title  \
# 0    32.0   Male      Bachelor's              Software Engineer
# 2    45.0   Male             PhD                 Senior Manager
# 4    52.0   Male        Master's                       Director
# 5    29.0   Male      Bachelor's              Marketing Analyst
# 7    31.0   Male      Bachelor's                  Sales Manager
# ..    ...    ...             ...                            ...
# 365  43.0   Male        Master's          Director of Marketing
# 367  41.0   Male      Bachelor's         Senior Product Manager
# 369  33.0   Male      Bachelor's        Junior Business Analyst
# 371  43.0   Male        Master's         Director of Operations
# 373  34.0   Male      Bachelor's  Senior Operations Coordinator
#
#      Years of Experience    Salary
# 0                    5.0   90000.0
# 2                   15.0  150000.0
# 4                   20.0  200000.0
# 5                    2.0   55000.0
# 7                    4.0   80000.0
# ..                   ...       ...
# 365                 18.0  170000.0
# 367                 14.0  150000.0
# 369                  4.0   60000.0
# 371                 19.0  170000.0
# 373                  7.0   90000.0
#
# [194 rows x 6 columns]

# %%
df[df['Job Title'] == 'Software Engineer']
# Out:
#     Age Gender Education Level          Job Title  Years of Experience  \
# 0  32.0   Male      Bachelor's  Software Engineer                  5.0
#
#     Salary
# 0  90000.0

# %%
df[df['Job Title'] == 'Director']
# Out:
#     Age Gender Education Level Job Title  Years of Experience    Salary
# 4  52.0   Male        Master's  Director                 20.0  200000.0

# %%
df[df['Salary'] >= 200000]
# Out:
#       Age Gender Education Level                 Job Title  \
# 4    52.0   Male        Master's                  Director
# 30   50.0   Male      Bachelor's                       CEO
# 53   47.0   Male        Master's             VP of Finance
# 83   52.0   Male             PhD  Chief Technology Officer
# 105  44.0   Male             PhD        Chief Data Officer
#
#      Years of Experience    Salary
# 4                   20.0  200000.0
# 30                  25.0  250000.0
# 53                  19.0  200000.0
# 83                  24.0  250000.0
# 105                 16.0  220000.0

# %%
df[(df['Salary'] >= 200000) & (df['Education Level']=='PhD')]
# Out:
#       Age Gender Education Level                 Job Title  \
# 83   52.0   Male             PhD  Chief Technology Officer
# 105  44.0   Male             PhD        Chief Data Officer
#
#      Years of Experience    Salary
# 83                  24.0  250000.0
# 105                 16.0  220000.0

# %%
data = df[(df['Salary'] >= 200000) | (df['Education Level']=='PhD')]
data.to_csv('filtered_data.csv')

# %%
data = df[(df['Salary'] >= 200000) | (df['Education Level']=='PhD')]
data.to_csv('filtered_data.csv')
data
# Out:
#       Age  Gender Education Level                        Job Title  \
# 2    45.0    Male             PhD                   Senior Manager
# 4    52.0    Male        Master's                         Director
# 9    38.0    Male             PhD                 Senior Scientist
# 17   39.0    Male             PhD                  Senior Engineer
# 28   43.0  Female             PhD                Senior Consultant
# 30   50.0    Male      Bachelor's                              CEO
# 34   46.0    Male             PhD                   Senior Manager
# 48   38.0    Male             PhD                 Senior Scientist
# 53   47.0    Male        Master's                    VP of Finance
# 57   43.0    Male             PhD                  Senior Engineer
# 63   47.0    Male             PhD            Senior Data Scientist
# 72   45.0    Male             PhD                Research Director
# 83   52.0    Male             PhD         Chief Technology Officer
# 90   36.0    Male             PhD              Principal Scientist
# 96   47.0    Male             PhD               Research Scientist
# 105  44.0    Male             PhD               Chief Data Officer
# 117  48.0    Male             PhD               Principal Engineer
# 124  44.0  Female             PhD                 Senior Scientist
# 133  47.0    Male             PhD        Senior Research Scientist
# 146  42.0  Female             PhD            Senior Data Scientist
# 152  43.0  Female             PhD          Senior Product Designer
# 158  51.0  Female             PhD      Director of Human Resources
# 167  46.0    Male             PhD                Senior Researcher
# 176  42.0  Female             PhD         Senior Marketing Manager
# 182  44.0  Female             PhD               Senior UX Designer
# 188  50.0  Female             PhD  Director of Sales and Marketing
# 197  45.0    Male             PhD              Senior Data Analyst
# 205  41.0  Female             PhD        Senior Marketing Director
# 211  45.0  Female             PhD          Senior Product Designer
# 217  50.0  Female             PhD           Director of Operations
# 226  46.0    Male             PhD            Senior Data Scientist
# 234  42.0  Female             PhD         Senior Marketing Manager
# 240  44.0  Female             PhD                Senior HR Manager
# 243  46.0    Male             PhD              Senior Data Analyst
# 252  45.0  Female             PhD          Senior Product Designer
# 258  50.0  Female             PhD           Director of Operations
# 262  46.0    Male             PhD            Senior Data Scientist
# 270  45.0    Male             PhD             Senior Data Engineer
# 276  46.0    Male             PhD              Senior Data Analyst
# 285  44.0  Female             PhD          Senior Product Designer
# 291  49.0    Male             PhD           Director of Operations
# 297  44.0    Male             PhD            Senior Data Scientist
# 303  45.0    Male             PhD             Senior Data Engineer
# 312  44.0  Female             PhD          Senior Product Designer
# 323  47.0    Male             PhD          Director of Engineering
# 326  43.0  Female             PhD            Senior Data Scientist
# 332  45.0  Female             PhD               Senior UX Designer
# 338  44.0  Female             PhD          Senior Business Analyst
# 344  44.0  Female             PhD             Senior Data Engineer
# 350  44.0  Female             PhD            Senior Data Scientist
# 356  45.0  Female             PhD               Senior UX Designer
# 362  44.0  Female             PhD          Senior Business Analyst
# 368  44.0  Female             PhD             Senior Data Engineer
# 374  44.0  Female             PhD          Senior Business Analyst
#
#      Years of Experience    Salary
# 2                   15.0  150000.0
# 4                   20.0  200000.0
# 9                   10.0  110000.0
# 17                  12.0  115000.0
# 28                  15.0  140000.0
# 30                  25.0  250000.0
# 34                  20.0  170000.0
# 48                  11.0  120000.0
# 53                  19.0  200000.0
# 57                  17.0  140000.0
# 63                  21.0  180000.0
# 72                  16.0  190000.0
# 83                  24.0  250000.0
# 90                  11.0  120000.0
# 96                  22.0  160000.0
# 105                 16.0  220000.0
# 117                 20.0  170000.0
# 124                 16.0  140000.0
# 133                 22.0  160000.0
# 146                 16.0  150000.0
# 152                 18.0  140000.0
# 158                 23.0  185000.0
# 167                 18.0  150000.0
# 176                 18.0  140000.0
# 182                 15.0  145000.0
# 188                 22.0  180000.0
# 197                 17.0  155000.0
# 205                 17.0  160000.0
# 211                 15.0  150000.0
# 217                 22.0  180000.0
# 226                 18.0  160000.0
# 234                 13.0  140000.0
# 240                 18.0  160000.0
# 243                 19.0  150000.0
# 252                 15.0  150000.0
# 258                 22.0  180000.0
# 262                 18.0  160000.0
# 270                 16.0  150000.0
# 276                 17.0  160000.0
# 285                 15.0  150000.0
# 291                 21.0  180000.0
# 297                 16.0  160000.0
# 303                 16.0  150000.0
# 312                 15.0  150000.0
# 323                 20.0  180000.0
# 326                 15.0  150000.0
# 332                 16.0  160000.0
# 338                 15.0  150000.0
# 344                 16.0  160000.0
# 350                 16.0  160000.0
# 356                 16.0  160000.0
# 362                 15.0  150000.0
# 368                 16.0  160000.0
# 374                 15.0  150000.0

# %%
data = df[((df['Salary'] >= 200000) | (df['Education Level']=='PhD')) & (df['Gender']=='Female')]
data.to_csv('filtered_data.csv')
data
# Out:
#       Age  Gender Education Level                        Job Title  \
# 28   43.0  Female             PhD                Senior Consultant
# 124  44.0  Female             PhD                 Senior Scientist
# 146  42.0  Female             PhD            Senior Data Scientist
# 152  43.0  Female             PhD          Senior Product Designer
# 158  51.0  Female             PhD      Director of Human Resources
# 176  42.0  Female             PhD         Senior Marketing Manager
# 182  44.0  Female             PhD               Senior UX Designer
# 188  50.0  Female             PhD  Director of Sales and Marketing
# 205  41.0  Female             PhD        Senior Marketing Director
# 211  45.0  Female             PhD          Senior Product Designer
# 217  50.0  Female             PhD           Director of Operations
# 234  42.0  Female             PhD         Senior Marketing Manager
# 240  44.0  Female             PhD                Senior HR Manager
# 252  45.0  Female             PhD          Senior Product Designer
# 258  50.0  Female             PhD           Director of Operations
# 285  44.0  Female             PhD          Senior Product Designer
# 312  44.0  Female             PhD          Senior Product Designer
# 326  43.0  Female             PhD            Senior Data Scientist
# 332  45.0  Female             PhD               Senior UX Designer
# 338  44.0  Female             PhD          Senior Business Analyst
# 344  44.0  Female             PhD             Senior Data Engineer
# 350  44.0  Female             PhD            Senior Data Scientist
# 356  45.0  Female             PhD               Senior UX Designer
# 362  44.0  Female             PhD          Senior Business Analyst
# 368  44.0  Female             PhD             Senior Data Engineer
# 374  44.0  Female             PhD          Senior Business Analyst
#
#      Years of Experience    Salary
# 28                  15.0  140000.0
# 124                 16.0  140000.0
# 146                 16.0  150000.0
# 152                 18.0  140000.0
# 158                 23.0  185000.0
# 176                 18.0  140000.0
# 182                 15.0  145000.0
# 188                 22.0  180000.0
# 205                 17.0  160000.0
# 211                 15.0  150000.0
# 217                 22.0  180000.0
# 234                 13.0  140000.0
# 240                 18.0  160000.0
# 252                 15.0  150000.0
# 258                 22.0  180000.0
# 285                 15.0  150000.0
# 312                 15.0  150000.0
# 326                 15.0  150000.0
# 332                 16.0  160000.0
# 338                 15.0  150000.0
# 344                 16.0  160000.0
# 350                 16.0  160000.0
# 356                 16.0  160000.0
# 362                 15.0  150000.0
# 368                 16.0  160000.0
# 374                 15.0  150000.0

# %%
# info()
df = pd.read_csv('Salary Data.csv')
df
# Out:
#       Age  Gender Education Level                      Job Title  \
# 0    32.0    Male      Bachelor's              Software Engineer
# 1    28.0  Female        Master's                   Data Analyst
# 2    45.0    Male             PhD                 Senior Manager
# 3    36.0  Female      Bachelor's                Sales Associate
# 4    52.0    Male        Master's                       Director
# ..    ...     ...             ...                            ...
# 370  35.0  Female      Bachelor's       Senior Marketing Analyst
# 371  43.0    Male        Master's         Director of Operations
# 372  29.0  Female      Bachelor's         Junior Project Manager
# 373  34.0    Male      Bachelor's  Senior Operations Coordinator
# 374  44.0  Female             PhD        Senior Business Analyst
#
#      Years of Experience    Salary
# 0                    5.0   90000.0
# 1                    3.0   65000.0
# 2                   15.0  150000.0
# 3                    7.0   60000.0
# 4                   20.0  200000.0
# ..                   ...       ...
# 370                  8.0   85000.0
# 371                 19.0  170000.0
# 372                  2.0   40000.0
# 373                  7.0   90000.0
# 374                 15.0  150000.0
#
# [375 rows x 6 columns]

# %%
# info()
df = pd.read_csv('Salary Data.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 375 entries, 0 to 374
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Age                  373 non-null    float64
#  1   Gender               373 non-null    object
#  2   Education Level      373 non-null    object
#  3   Job Title            373 non-null    object
#  4   Years of Experience  373 non-null    float64
#  5   Salary               373 non-null    float64
# dtypes: float64(3), object(3)
# memory usage: 17.7+ KB

# %%
import pandas as pd
data = {
    'sn':[1,2,3,4,5],
    'name':['Ram','Shyam','Hari','Sita','Gita'],
    'add':['Bhaktapu','Lalitpur','Kathmandu','Jhapa','Chitwan'],
    'age':[34,56,34,23,67]
}
df = pd.DataFrame(data)
df
# Out:
#    sn   name        add  age
# 0   1    Ram   Bhaktapu   34
# 1   2  Shyam   Lalitpur   56
# 2   3   Hari  Kathmandu   34
# 3   4   Sita      Jhapa   23
# 4   5   Gita    Chitwan   67

# %%
import pandas as pd
data = {
    'sn':[1,2,3,4,5],
    'name':['Ram','Shyam','Hari','Sita','Gita'],
    'add':['Bhaktapu','Lalitpur','Kathmandu','Jhapa','Chitwan'],
    'age':[34,56,34,23,67]
}
df = pd.DataFrame(data)
df.to_csv('info.csv')
df
# Out:
#    sn   name        add  age
# 0   1    Ram   Bhaktapu   34
# 1   2  Shyam   Lalitpur   56
# 2   3   Hari  Kathmandu   34
# 3   4   Sita      Jhapa   23
# 4   5   Gita    Chitwan   67

# %%
data = [['Ram',34,'Kathmandu'],
        [2, 'Shyam',45,'Bhaktapu',],
        [3,'Hari',67,'Lalitpur']]
col = ["sn",'name','age','add']
df = pd.DataFrame(data,columns=col)
df
# Out:
#     sn   name        age       add
# 0  Ram     34  Kathmandu      None
# 1    2  Shyam         45  Bhaktapu
# 2    3   Hari         67  Lalitpur

# %%
data = [['Ram',34,'Kathmandu'],
        [2, 'Shyam',45,'Bhaktapu',],
        [3,'Hari',67,'Lalitpur']]
col = ["sn",'name','age','add']
df = pd.DataFrame(data,columns=col)
df.to_csv('info.csv')
df
# Out:
#     sn   name        age       add
# 0  Ram     34  Kathmandu      None
# 1    2  Shyam         45  Bhaktapu
# 2    3   Hari         67  Lalitpur

# %%
import csv
csv_columns = ['Name', 'Age', 'Address']
dict = [
    {'Name':'Aayush','Age':23,'Address':'Katmandu'},
    {'Name':'Shyam','Age':33,'Address':'Patan'}
]

csvfile = open("data.csv", 'w')
writer = csv.DictWriter(csvfile, fieldnames=csv_columns)
writer.writeheader()
for data in dict:
    writer.writerow(data)
csvfile.close()

# %%
# import csv
with open('data.csv') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        print(row)
# Out:
# {'Name': 'Aayush', 'Age': '23', 'Address': 'Katmandu'}
# {'Name': 'Shyam', 'Age': '33', 'Address': 'Patan'}

# %%
data = []
with open('data.csv') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        data.append(row)
data
# Out:
# [{'Name': 'Aayush', 'Age': '23', 'Address': 'Katmandu'},
#  {'Name': 'Shyam', 'Age': '33', 'Address': 'Patan'}]

# %%
# concat

df1 = pd.DataFrame({'sn':[1,2,3],
                   'name':['Ram','Shyam','Hari'],
                   'add':['Kathmandu','Bhaktapur','lalitpur']})
df2 = pd.DataFrame({'sn':[4,5,6],
                    'name':['Akash','Baral','Harry'],
                    'add':['Kathmandu','Bhaktapur','Lalitpur']})
df = pd.concat([df1,df2])
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 3
#       1 # concat
# ----> 3 df1 = pd.DataFrame({'sn':[1,2,3],
#       4                    'name':['Ram','Shyam','Hari'],
#       5                    'add':['Kathmandu','Bhaktapur','lalitpur']})
#       6 df2 = pd.DataFrame({'sn':[4,5,6],
#       7                     'name':['Akash','Baral','Harry'],
#       8                     'add':['Kathmandu','Bhaktapur','Lalitpur']})
#       9 df = pd.concat([df1,df2])
#
# NameError: name 'pd' is not defined
